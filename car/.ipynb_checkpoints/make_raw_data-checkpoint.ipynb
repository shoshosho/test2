# %%
import pandas as pd
import numpy as np
import pickle

# %%
#面倒な前処理部分は今回エクセル上で実施済み
#別途前処理をするコードが必要
#

# %%
#国勢調査
kokusei = pd.read_csv("/Users/01017387/Desktop/しごと/data/car用/加工済み/kokuseichosa_2015_for_merge.csv")
print(kokusei.columns)
#全てを英字変換する必要あり
kokusei.columns=["pref_code", "pref_city_code", "capital_city_flg", "city_categories", "chiho", "city_name",
                 "population", "h22_kumikae_population", "population_changed_from_h22_to_h27", "rate_population_changed_from_h22_to_h27",
                 "gross_area", "population_density", "ave_age_from_h22_to_h27", "med_age_from_h22_to_h27", "population",
                 "population_under_15old", "population_from_15_to_64_old", "population_over_65old", "rate_population_under_15_year_old",
                 "rate_population_from_15_to_64_old", "rate_population_over_65old", "population_male","population_male_under_15old",
                 "population_male_from_15_to_64_old", "population_male_over_65old", "rate_population_male_under_15old",
                 "rate_population_male_from_15_to_64_old", "rate_population_male_over_65old", "population_female",
                 "population_female_under_15old", "population_female_from_15_to_64_old", "population_female_over_65old",
                 "rate_population_female_under_15old", "rate_population_female_from_15_to_64_old", "rate_population_female_over_65old",
                 "rate_population_male_to female", "population_jap", "population_no_jap", "num_of_family", "num_of_normal_family",
                 "num_of_family_in_facilities", "h22_kumikae_family", "num_of_normal_family", "num_of_nuclear_family",
                 "num_of_family_no_children", "num_of_family_with_children", "num_of_father_and_children", "num_of_mother_and_children",
                 "num_of_singles", "num_of_over_65old_singles", "num_of_old_married_couples_no_children", "num_of_3generation_family",]
kokusei.columns
print(kokusei.shape)
kokusei.head()
# Out:
# Index(['都道府県\rコード', '都道府県・\r市区町村コード', '都道府県庁\r所在市', '市など\rの別', '都道府県名',
#        '都道府県・市区町村名', '人口総数', '平成22年組替人口', '平成22年～27年の人口増減数', '平成22年～27年の人口増減率',
#        '平成22年～27年の面積', '平成22年～27年の人口密度', '平成22年～27年の平均年齢', '平成22年～27年の年齢中位数',
#        '年齢（総数）総数\r人口', '年齢（総数）15歳未満\r人口', '年齢（総数）15～64歳\r人口',
#        '年齢（総数）65歳以上\r人口', '年齢別割合（総数）15歳未満\r人口割合', '年齢別割合（総数）15～64歳\r人口割合',
#        '年齢別割合（総数）65歳以上\r人口割合', '年齢（男）総数\r人口', '年齢（男）15歳未満\r人口',
#        '年齢（男）15～64歳\r人口', '年齢（男）65歳以上\r人口', '年齢別割合（男）15歳未満\r人口割合',
#        '年齢別割合（男）15～64歳\r人口割合', '年齢別割合（男）65歳以上\r人口割合', '年齢（女）総数\r人口',
#        '年齢（女）15歳未満\r人口', '年齢（女）15～64歳\r人口', '年齢（女）65歳以上\r人口',
#        '年齢別割合（女）15歳未満\r人口割合', '年齢別割合（女）15～64歳\r人口割合', '年齢別割合（女）65歳以上\r人口割合',
#        '年齢別割合（女）人口性比（女100人につき男）', '日本人', '外国人', '世帯総数', '一般世帯', '施設等の世帯',
#        '平成22年組替世帯総数', '一般世帯数', '一般世帯数うち\r核家族世帯', '一般世帯数うち\r夫婦のみの世帯',
#        '一般世帯数うち\r夫婦と子供\rから成る世帯', '一般世帯数うち\r男親と子供\rから成る世帯',
#        '一般世帯数うち\r女親と子供\rから成る世帯', '一般世帯数うち\r単独世帯', '一般世帯数うち\r65歳以上の高齢単身者世帯',
#        '一般世帯数（再掲）\r高齢夫婦世帯\r（夫65歳以上妻60歳以上の夫婦1組のみの一般世帯）', '一般世帯数（再掲）\r３世代世帯'],
#       dtype='object')
# (1959, 52)
#    pref_code  pref_city_code  capital_city_flg  city_categories chiho  \
# 0        1.0          1100.0               1.0              1.0   北海道
# 1        1.0          1101.0               NaN              0.0   北海道
# 2        1.0          1102.0               NaN              0.0   北海道
# 3        1.0          1103.0               NaN              0.0   北海道
# 4        1.0          1104.0               NaN              0.0   北海道
#
#   city_name population h22_kumikae_population  \
# 0       札幌市  1,952,356              1,913,545
# 1    札幌市中央区    237,627                220,189
# 2     札幌市北区    285,321                278,781
# 3     札幌市東区    261,912                255,873
# 4    札幌市白石区    209,584                204,259
#
#   population_changed_from_h22_to_h27  rate_population_changed_from_h22_to_h27  \
# 0                             38,811                                      2.0
# 1                             17,438                                      7.9
# 2                              6,540                                      2.3
# 3                              6,039                                      2.4
# 4                              5,325                                      2.6
#
#              ...             num_of_normal_family num_of_nuclear_family  \
# 0            ...                          920,415               493,644
# 1            ...                          131,819                52,695
# 2            ...                          133,477                70,121
# 3            ...                          124,251                65,606
# 4            ...                          104,464                51,433
#
#    num_of_family_no_children  num_of_family_with_children  \
# 0                    194,424                      213,793
# 1                     22,332                       21,118
# 2                     26,738                       31,744
# 3                     24,770                       28,880
# 4                     19,992                       21,661
#
#   num_of_father_and_children num_of_mother_and_children num_of_singles  \
# 0                     10,049                     75,378        375,242
# 1                        878                      8,367         73,164
# 2                      1,414                     10,225         55,247
# 3                      1,401                     10,555         51,879
# 4                      1,232                      8,548         47,852
#
#   num_of_over_65old_singles  num_of_old_married_couples_no_children  \
# 0                   104,650                                  98,660
# 1                    14,403                                   9,542
# 2                    14,688                                  14,221
# 3                    14,050                                  12,156
# 4                    11,906                                   8,994
#
#    num_of_3generation_family
# 0                     20,124
# 1                      1,221
# 2                      3,164
# 3                      2,504
# 4                      1,920
#
# [5 rows x 52 columns]

# %%
#保有台数
hoyu = pd.read_csv("/Users/01017387/Desktop/しごと/data/car用/加工済み/2015_hoyu_daisu.csv",encoding="utf-8")
print(hoyu.columns)
hoyu.columns = ["chiho", "num_of_cars_all", "num_of_cars_kei", "num_of_cars_normal", "num_of_familiy", "cars_per_person",
                "normal_cars_per_person", "kei_cars_per_person", "kei_rate", "normal_rate", "kei_share_in_JP", "normal_share_in_JP",
                "guess_2nd_hand_kei_car_sales_per_year", "guess_2nd_hand_normal_car_sales_per_year", "guess_2nd_hand_car_all_sales_per_year"]
print(hoyu.shape)
hoyu.head()
# Out:
# Index(['都道府県名', '乗用車', '軽', '普通', '世帯数', '車両数/世帯数', '普通車両数/世帯数', '軽車両数/世帯数',
#        '軽率', '普通率', '軽シェア', '普通シェア', '軽シェア×中古販売数', '普通シェア×中古販売数', '中古車販売台数'],
#       dtype='object')
# (47, 15)
#   chiho num_of_cars_all  num_of_cars_kei num_of_cars_normal num_of_familiy  \
# 0   北海道       2,805,265          1142062          1,663,203      2,734,906
# 1    青森         728,253           455493            272,760        586,148
# 2    岩手         738,199           458943            279,256        517,845
# 3    宮城       1,282,869           617560            665,309        961,574
# 4    秋田         594,158           374063            220,095        424,208
#
#    cars_per_person  normal_cars_per_person  kei_cars_per_person kei_rate  \
# 0         1.025726                0.608139             0.417587   40.71%
# 1         1.242439                0.465343             0.777096   62.55%
# 2         1.425521                0.539266             0.886256   62.17%
# 3         1.334134                0.691896             0.642239   48.14%
# 4         1.400629                0.518837             0.881791   62.96%
#
#   normal_rate kei_share_in_JP normal_share_in_JP  \
# 0      59.29%           3.77%              5.39%
# 1      37.45%           1.50%              0.88%
# 2      37.83%           1.51%              0.91%
# 3      51.86%           2.04%              2.16%
# 4      37.04%           1.23%              0.71%
#
#   guess_2nd_hand_kei_car_sales_per_year  \
# 0                                37,693
# 1                                15,033
# 2                                15,147
# 3                                20,382
# 4                                12,346
#
#   guess_2nd_hand_normal_car_sales_per_year  \
# 0                                  161,743
# 1                                   26,525
# 2                                   27,157
# 3                                   64,700
# 4                                   21,404
#
#   guess_2nd_hand_car_all_sales_per_year
# 0                               199,436
# 1                                41,559
# 2                                42,304
# 3                                85,082
# 4                                33,749

# %%
#保有台数のキーの変更
# hoyu.rename(columns={"県名":"都道府県名"})
hoyu.head(2)
# hoyu["県名"]
#国勢調査と保有台数のマージ
koku_hoyu = pd.merge(kokusei,hoyu,on="chiho",how="left")
print(koku_hoyu.shape)
koku_hoyu.head()
#OK
# Out:
# (1959, 66)
#    pref_code  pref_city_code  capital_city_flg  city_categories chiho  \
# 0        1.0          1100.0               1.0              1.0   北海道
# 1        1.0          1101.0               NaN              0.0   北海道
# 2        1.0          1102.0               NaN              0.0   北海道
# 3        1.0          1103.0               NaN              0.0   北海道
# 4        1.0          1104.0               NaN              0.0   北海道
#
#   city_name population h22_kumikae_population  \
# 0       札幌市  1,952,356              1,913,545
# 1    札幌市中央区    237,627                220,189
# 2     札幌市北区    285,321                278,781
# 3     札幌市東区    261,912                255,873
# 4    札幌市白石区    209,584                204,259
#
#   population_changed_from_h22_to_h27  rate_population_changed_from_h22_to_h27  \
# 0                             38,811                                      2.0
# 1                             17,438                                      7.9
# 2                              6,540                                      2.3
# 3                              6,039                                      2.4
# 4                              5,325                                      2.6
#
#                    ...                   cars_per_person  \
# 0                  ...                          1.025726
# 1                  ...                          1.025726
# 2                  ...                          1.025726
# 3                  ...                          1.025726
# 4                  ...                          1.025726
#
#   normal_cars_per_person  kei_cars_per_person  kei_rate normal_rate  \
# 0               0.608139             0.417587    40.71%      59.29%
# 1               0.608139             0.417587    40.71%      59.29%
# 2               0.608139             0.417587    40.71%      59.29%
# 3               0.608139             0.417587    40.71%      59.29%
# 4               0.608139             0.417587    40.71%      59.29%
#
#   kei_share_in_JP normal_share_in_JP guess_2nd_hand_kei_car_sales_per_year  \
# 0           3.77%              5.39%                                37,693
# 1           3.77%              5.39%                                37,693
# 2           3.77%              5.39%                                37,693
# 3           3.77%              5.39%                                37,693
# 4           3.77%              5.39%                                37,693
#
#    guess_2nd_hand_normal_car_sales_per_year  \
# 0                                   161,743
# 1                                   161,743
# 2                                   161,743
# 3                                   161,743
# 4                                   161,743
#
#    guess_2nd_hand_car_all_sales_per_year
# 0                                199,436
# 1                                199,436
# 2                                199,436
# 3                                199,436
# 4                                199,436
#
# [5 rows x 66 columns]

# %%
#pickle形式でdataframeを保存
#超はやい
#保存
with open('test.pkl','wb') as f1:
    pickle.dump(koku_hoyu,f1)

# %%
#読み込み
with open('test.pkl','rb') as f2:
    data=pickle.load(f2)

# %%
#以下車データの読み込み
kuruma = pd.read_csv("/Users/01017387/Desktop/しごと/data/car用/加工済み/物件*問い合わせ/tes.csv")
kuruma["b.shikuchoson_jusho_kj"] = kuruma["b.shikuchoson_jusho_kj"].str.replace('ヶ', 'ケ')
kuruma.head()
kuruma.tail()
# Out:
#      a.keisai_shashu_kj a.keisai_grade_name  a.door_su a.body_type_name  \
# 4995              ハイエース      2.7GLロングミドルルーフ        4.0             ミニバン
# 4996              ハイエース      2.7GLロングミドルルーフ        4.0             ミニバン
# 4997          スカイラインクーペ            3.5350GT        2.0              クーペ
# 4998                マーチ              1.212c        5.0           ハッチバック
# 4999                マーチ              1.212c        5.0           ハッチバック
#
#       a.mission_flg  a.mt_mode_at_flg  a.handle_flg  a.air_conditioner_flg  \
# 4995             26                 0             1                      1
# 4996             26                 0             1                      1
# 4997              3                 1             1                      1
# 4998              2                 0             1                      1
# 4999              2                 0             1                      1
#
#       a.power_steering_flg  a.power_window_flg     ...      \
# 4995                     1                   1     ...
# 4996                     1                   1     ...
# 4997                     1                   1     ...
# 4998                     1                   1     ...
# 4999                     1                   1     ...
#
#       a.hdd_navigation_flg  a.katashiki     b.toiawase_date  b.todofuken_cd  \
# 4995                     1  CBA-TRH214W  2015-09-3016:22:47              36
# 4996                     1  CBA-TRH214W  2015-11-0913:19:48              25
# 4997                     0     UA-CPV35  2015-07-0115:17:05              63
# 4998                     0     CBA-AK12  2015-02-0220:47:21              33
# 4999                     0     CBA-AK12  2015-02-0318:45:06              33
#
#       b.todofuken_jusho_kj  b.shikuchoson_jusho_kj    b.zip  b.hojin_cd  \
# 4995                  神奈川県                横浜市青葉区桜台  2270061       81702
# 4996                   福島県                相馬郡新地町小川  9792703       81702
# 4997                   広島県                 呉市広津久茂町     null      307963
# 4998                   埼玉県                     所沢市     null      307963
# 4999                   埼玉県                   入間市宮寺  3580014      307963
#
#       b.madoguchi_cd  b.yyyymmdd
# 4995               1    20161213
# 4996               1    20161213
# 4997               1    20161213
# 4998               1    20161213
# 4999               1    20161213
#
# [5 rows x 30 columns]

# %%
#県単位、市区町村単位での地方別集計（問い合わせ）
#入ってるレベル感が違う
#市区町村が最後の文字になるように調整した変数を作成する

#市区町村マスタと一致する部分のみ残す
#市区町村マスタを辞書型で作成する
#県に紐づく市区町村をリストで保持しておく
dl = pd.read_csv("/Users/01017387/Desktop/しごと/data/car用/加工済み/市区町村マスタ.csv",names=["pref","city"])
dl.head()

#h市区町村表記揺れを消したい
dl["city"] = dl["city"].str.replace('ヶ', 'ケ')

pre = dl["pref"].unique() #array

dl["count"] =1
num = dl.groupby("pref").sum()

dc = num.to_dict()
dic = dc["count"]

biglis = []
c=0
#都道府県別市区町村の格納
for i in pre:
    tmplis = []
    for k in range(int(dic[i])):
        exec("tmplis.append(dl['city']["+str(c)+"])")
        c +=1
    #最初の要素を最後に持ってくる
    
    push_to_last = tmplis.pop(0)
    tmplis.append(push_to_last)
    biglis.append(tmplis)

#辞書の作成
dicts = {key: value for (key, value) in zip(pre,biglis)}

#dfの各要素について、辞書のどこに一致するかを見て、ループで部分一致を探す

# %%
#車種・グレード別集計（問い合わせ）
#車種・グレード別集計（お気に入り）

# %%
ken = kuruma["b.todofuken_jusho_kj"].values
aa = kuruma["b.shikuchoson_jusho_kj"].values
aa
bb = []
counter =[]
#市区町村を格納してる順番が良くないので、並び替えが必要
for k,i in zip(ken,aa):
    count=0
    for l in dicts[k]:
        if l in i:
            bb.append(l)
            counter.append(1)
            break
        count+=1
        if count >=(len(dicts[k])):
            bb.append("")
            counter.append(0)
            break
#概ねOKだけど、県名の後に直接郡の名前が来るケースに対応できていない
→修正する？

# %%
print(len(bb))
print(len(aa))
print(len(ken))
print(len(counter))
print(sum(counter))
# bb
# aa
counter.index(0)
# bb[172]
# aa[172]
print(aa[10:18])
print(bb[10:18])
# ken[172]
# Out:
# 5000
# 5000
# 5000
# 5000
# 4799
# ['神戸市長田区源平町' '文京区根津' '伊勢崎市国定町' '黒部市堀切' '苫田郡' '柏市高柳' '阿蘇郡' '世田谷区等々力']
# ['神戸市長田区', '文京区', '伊勢崎市', '黒部市', '', '柏市', '', '世田谷区']

# %%
ar = np.array([aa,bb,counter])
ar
an = pd.DataFrame([aa,bb,counter]).T
an.columns=["元","変更後","見つかった？"]
an.head()
ann =an.ix[an["見つかった？"] ==0].ix[an["元"] !="null"]

import japandas as jpd
ann["元1"] = ann["元"].str.z2h(kana=False, alpha=False, digit=True)
sakana = ann.ix[ann["元1"].str.extract('([0-9]+)').notnull()]
sakana
# Out:
# /Users/01017387/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:10: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#                      元 変更後 見つかった？                元1
# 194            １５０００３３          0           1500033
# 548            １６９００６２          0           1690062
# 1045           ０６４０９５３          0           0640953
# 1244          ９１９−１３２４          0          919−1324
# 2414  南会津郡桧枝岐村字下ノ原１００４          0  南会津郡桧枝岐村字下ノ原1004
# 3253          ００１−０９２４          0          001−0924

# %%
# Out:
# ['千葉市中央区',
#  '千葉市花見川区',
#  '千葉市稲毛区',
#  '千葉市若葉区',
#  '千葉市緑区',
#  '千葉市美浜区',
#  '銚子市',
#  '市川市',
#  '船橋市',
#  '館山市',
#  '木更津市',
#  '松戸市',
#  '野田市',
#  '茂原市',
#  '成田市',
#  '佐倉市',
#  '東金市',
#  '旭市',
#  '習志野市',
#  '柏市',
#  '勝浦市',
#  '市原市',
#  '流山市',
#  '八千代市',
#  '我孫子市',
#  '鴨川市',
#  '鎌ケ谷市',
#  '君津市',
#  '富津市',
#  '浦安市',
#  '四街道市',
#  '袖ケ浦市',
#  '八街市',
#  '印西市',
#  '白井市',
#  '富里市',
#  '南房総市',
#  '匝瑳市',
#  '香取市',
#  '山武市',
#  'いすみ市',
#  '大網白里市',
#  '酒々井町',
#  '栄町',
#  '神崎町',
#  '多古町',
#  '東庄町',
#  '九十九里町',
#  '芝山町',
#  '横芝光町',
#  '一宮町',
#  '睦沢町',
#  '長生村',
#  '白子町',
#  '長柄町',
#  '長南町',
#  '大多喜町',
#  '御宿町',
#  '鋸南町',
#  '千葉市']

# %%
po = pd.read_csv("/Users/01017387/Downloads/all.txt",encoding="cp932")
# 全部載ってそうなので、郡とか村の取り残しにはこっちを使う
# Out:
#      団体コード     団体名         ふりがな       ふりがな小書     新郵便番号                     住所  \
# 0    10006     北海道          NaN          NaN  060-8588          札幌市中央区北3条西6-1
# 1    11002     札幌市        さつぽろし        さっぽろし  060-8611          札幌市中央区北1条西2丁目
# 2    11011  札幌市中央区  さつぽろしちゆうおうく  さっぽろしちゅうおうく  060-8612         札幌市中央区南3条西11丁目
# 3    11029   札幌市北区     さつぽろしきたく     さっぽろしきたく  001-8612       札幌市北区北24条西6丁目1-1
# 4    11037   札幌市東区    さつぽろしひがしく    さっぽろしひがしく  065-8612       札幌市東区北11条東7丁目1-1
# 5    11045  札幌市白石区   さつぽろししろいしく   さっぽろししろいしく  003-8612       札幌市白石区本郷通3丁目北1-1
# 6    11053  札幌市豊平区   さつぽろしとよひらく   さっぽろしとよひらく  062-8612      札幌市豊平区平岸6条10丁目1-1
# 7    11061   札幌市南区    さつぽろしみなみく    さっぽろしみなみく  005-8612       札幌市南区真駒内幸町2丁目2-1
# 8    11070   札幌市西区     さつぽろしにしく     さっぽろしにしく  063-8612        札幌市西区琴似2条7丁目1-1
# 9    11088  札幌市厚別区   さつぽろしあつべつく   さっぽろしあつべつく  004-8612     札幌市厚別区厚別中央1条5丁目3-2
# 10   11096  札幌市手稲区    さつぽろしていねく    さっぽろしていねく  006-8612     札幌市手稲区前田1条11丁目1-10
# 11   11100  札幌市清田区    さつぽろしきよたく    さっぽろしきよたく  004-8613       札幌市清田区平岡1条1丁目2-1
# 12   12025     函館市        はこだてし        はこだてし  040-8666             函館市東雲町4-13
# 13   12033     小樽市         おたるし         おたるし  047-8660            小樽市花園2-12-1
# 14   12041     旭川市       あさひかわし       あさひかわし  070-8525              旭川市6条通9丁目
# 15   12050     室蘭市        むろらんし        むろらんし  051-8511               室蘭市幸町1-2
# 16   12068     釧路市         くしろし         くしろし  085-8505              釧路市黒金町7-5
# 17   12076     帯広市        おびひろし        おびひろし  080-8670             帯広市西5条南7-1
# 18   12084     北見市         きたみし         きたみし  090-8509  北見市大通西2丁目1番地 まちきた大通ビル
# 19   12092     夕張市        ゆうばりし        ゆうばりし  068-0492               夕張市本町4-2
# 20   12106    岩見沢市       いわみざわし       いわみざわし  068-8686           岩見沢市鳩が丘1-1-1
# 21   12114     網走市        あばしりし        あばしりし  093-8555             網走市南6条東4丁目
# 22   12122     留萌市         るもいし         るもいし  077-8601              留萌市幸町1-11
# 23   12131    苫小牧市       とまこまいし       とまこまいし  053-8722            苫小牧市旭町4-5-6
# 24   12149     稚内市       わつかないし       わっかないし  097-8686           稚内市中央3-13-15
# 25   12157     美唄市         びばいし         びばいし  072-8660           美唄市西3条南1-1-1
# 26   12165     芦別市        あしべつし        あしべつし  075-8711             芦別市北1条東1-3
# 27   12173     江別市         えべつし         えべつし  067-8674                江別市高砂町6
# 28   12181     赤平市        あかびらし        あかびらし  079-1192               赤平市泉町4-1
# 29   12190     紋別市        もんべつし        もんべつし  094-8707            紋別市幸町2-1-18
# ..     ...     ...          ...          ...       ...                    ...
# 370  72028   会津若松市     あいづわかまつし     あいづわかまつし  965-8601           会津若松市東栄町3-46
# 371  72036     郡山市       こおりやまし       こおりやまし  963-8601            郡山市朝日1-23-7
# 372  72044    いわき市         いわきし         いわきし  970-8686             いわき市平字梅本21
# 373  72052     白河市        しらかわし        しらかわし  961-8602             白河市八幡小路7-1
# 374  72079    須賀川市        すかがわし        すかがわし  962-8601             須賀川市八幡町135
# 375  72087    喜多方市        きたかたし        きたかたし  966-8601        喜多方市字御清水東7244-2
# 376  72095     相馬市         そうまし         そうまし  976-8601            相馬市中村字大手先13
# 377  72109    二本松市       にほんまつし       にほんまつし  964-8601            二本松市金色403-1
# 378  72117     田村市         たむらし         たむらし  963-4393        田村市船引町船引字馬場川原20
# 379  72125    南相馬市      みなみそうまし      みなみそうまし  975-8686          南相馬市原町区本町2-27
# 380  72133     伊達市          だてし          だてし  960-0692           伊達市保原町字舟橋180
# 381  72141     本宮市        もとみやし        もとみやし  969-1192            本宮市本宮字万世212
# 382  73016     桑折町        こおりまち        こおりまち  969-1692           伊達郡桑折町字東大隅18
# 383  73032     国見町        くにみまち        くにみまち  969-1792     伊達郡国見町大字藤田字一丁田二1-7
# 384  73083     川俣町       かわまたまち       かわまたまち  960-1492           伊達郡川俣町字五百田30
# 385  73229     大玉村       おおたまむら       おおたまむら  969-1392          安達郡大玉村玉井字星内70
# 386  73423     鏡石町      かがみいしまち      かがみいしまち  969-0492           岩瀬郡鏡石町不時沼345
# 387  73440     天栄村       てんえいむら       てんえいむら  962-0592       岩瀬郡天栄村大字下松本字原畑78
# 388  73628     下郷町       しもごうまち       しもごうまち  969-5345     南会津郡下郷町大字塩生字大石1000
# 389  73644    檜枝岐村      ひのえまたむら      ひのえまたむら  967-0525        南会津郡檜枝岐村字下ノ原880
# 390  73679     只見町        ただみまち        ただみまち  968-0498     南会津郡只見町大字只見字雨堤1039
# 391  73687    南会津町     みなみあいづまち     みなみあいづまち  967-0004   南会津郡南会津町田島字後原甲3531-1
# 392  74021    北塩原村     きたしおばらむら     きたしおばらむら  966-0485    耶麻郡北塩原村大字北山字姥ヶ作3151
# 393  74055    西会津町      にしあいづまち      にしあいづまち  969-4495    耶麻郡西会津町野沢字下小屋上乙3261
# 394  74071     磐梯町       ばんだいまち       ばんだいまち  969-3392     耶麻郡磐梯町大字磐梯字中ノ橋1855
# 395  74080    猪苗代町      いなわしろまち      いなわしろまち  969-3123          耶麻郡猪苗代町字城南100
# 396  74217   会津坂下町     あいづばんげまち     あいづばんげまち  969-6592     河沼郡会津坂下町字市中三番甲3662
# 397  74225     湯川村        ゆがわむら        ゆがわむら  969-3593       河沼郡湯川村大字清水田字長瀞18
# 398  74233     柳津町       やないづまち       やないづまち  969-7201      河沼郡柳津町大字柳津字下平乙234
# 399  74446     三島町        みしままち        みしままち  969-7511       大沼郡三島町大字宮下字宮下350
#
#              電話番号
# 0    011-231-4111
# 1    011-211-2111
# 2    011-231-2400
# 3    011-757-2400
# 4    011-741-2400
# 5    011-861-2400
# 6    011-822-2400
# 7    011-582-2400
# 8    011-641-2400
# 9    011-895-2400
# 10   011-681-2400
# 11   011-889-2400
# 12   0138-21-3111
# 13   0134-32-4111
# 14   0166-26-1111
# 15   0143-22-1111
# 16   0154-23-5151
# 17   0155-24-4111
# 18   0157-23-7111
# 19   0123-52-3131
# 20   0126-23-4111
# 21   0152-44-6111
# 22   0164-42-1801
# 23   0144-32-6111
# 24   0162-23-6161
# 25   0126-62-3131
# 26   0124-22-2111
# 27   011-382-4141
# 28   0125-32-2211
# 29   0158-24-2111
# ..            ...
# 370  0242-39-1111
# 371  024-924-2491
# 372  0246-22-1111
# 373  0248-22-1111
# 374  0248-75-1111
# 375  0241-24-5211
# 376  0244-37-2120
# 377  0243-23-1111
# 378  0247-81-2111
# 379  0244-22-2111
# 380  024-575-1111
# 381  0243-33-1111
# 382  024-582-2111
# 383  024-585-2111
# 384  024-566-2111
# 385  0243-48-3131
# 386  0248-62-2111
# 387  0248-82-2111
# 388  0241-69-1122
# 389  0241-75-2500
# 390  0241-82-5210
# 391  0241-62-6100
# 392  0241-23-3111
# 393  0241-45-2211
# 394  0242-74-1221
# 395  0242-62-2111
# 396  0242-84-1503
# 397  0241-27-8800
# 398  0241-42-2112
# 399  0241-48-5515
#
# [400 rows x 7 columns]

# %%
po["code"] = po["団体コード"]/10000.astype(int)
po.head()

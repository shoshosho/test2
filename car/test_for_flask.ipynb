# %%
import pandas as pd
import dask.dataframe as dd
import numpy as np

# %%
a = pd.read_csv("/Users/01017387/Desktop/しごと/data/car用/加工済み/2015_hoyu_daisu.csv")
a.describe()
# Out:
#                   軽    車両数/世帯数  普通車両数/世帯数   軽車両数/世帯数
# count  4.700000e+01  47.000000  47.000000  47.000000
# mean   6.446647e+05   1.321430   0.565889   0.755541
# std    3.220118e+05   0.291403   0.166607   0.227480
# min    2.401700e+05   0.474985   0.272395   0.119366
# 25%    3.813550e+05   1.135978   0.453682   0.638562
# 50%    5.825350e+05   1.348482   0.534593   0.841489
# 75%    8.115235e+05   1.537529   0.677955   0.892889
# max    1.583760e+06   1.798576   0.921418   1.040254

# %%
a.head()
# Out:
#   都道府県名        乗用車        軽         普通        世帯数   車両数/世帯数  普通車両数/世帯数  \
# 0   北海道  2,805,265  1142062  1,663,203  2,734,906  1.025726   0.608139
# 1    青森    728,253   455493    272,760    586,148  1.242439   0.465343
# 2    岩手    738,199   458943    279,256    517,845  1.425521   0.539266
# 3    宮城  1,282,869   617560    665,309    961,574  1.334134   0.691896
# 4    秋田    594,158   374063    220,095    424,208  1.400629   0.518837
#
#    軽車両数/世帯数      軽率     普通率   軽シェア  普通シェア 軽シェア×中古販売数 普通シェア×中古販売数  中古車販売台数
# 0  0.417587  40.71%  59.29%  3.77%  5.39%     37,693     161,743  199,436
# 1  0.777096  62.55%  37.45%  1.50%  0.88%     15,033      26,525   41,559
# 2  0.886256  62.17%  37.83%  1.51%  0.91%     15,147      27,157   42,304
# 3  0.642239  48.14%  51.86%  2.04%  2.16%     20,382      64,700   85,082
# 4  0.881791  62.96%  37.04%  1.23%  0.71%     12,346      21,404   33,749

# %%
#文字列への対応
#小文字に統一、%は抜く、
# .str.lower()
a.dtypes != np.float64

# a[u"軽率"] = a[u"軽率"].apply(lambda x :x.replace("%","")).astype(float)
# a["軽率"].head()
# Out:
# 都道府県名           True
# 乗用車             True
# 軽               True
# 普通              True
# 世帯数             True
# 車両数/世帯数        False
# 普通車両数/世帯数      False
# 軽車両数/世帯数       False
# 軽率             False
# 普通率             True
# 軽シェア            True
# 普通シェア           True
# 軽シェア×中古販売数      True
# 普通シェア×中古販売数     True
# 中古車販売台数         True
# dtype: bool

# %%
a.describe()
# Out:
#                   軽    車両数/世帯数  普通車両数/世帯数   軽車両数/世帯数
# count  4.700000e+01  47.000000  47.000000  47.000000
# mean   6.446647e+05   1.321430   0.565889   0.755541
# std    3.220118e+05   0.291403   0.166607   0.227480
# min    2.401700e+05   0.474985   0.272395   0.119366
# 25%    3.813550e+05   1.135978   0.453682   0.638562
# 50%    5.825350e+05   1.348482   0.534593   0.841489
# 75%    8.115235e+05   1.537529   0.677955   0.892889
# max    1.583760e+06   1.798576   0.921418   1.040254

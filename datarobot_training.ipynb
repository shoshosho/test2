# %%
import datarobot as dr

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
a = np.random.randint(0,high=100,size=10000)
for i in range(10):
    a += np.random.randint(0,high=100,size=10000)

# %%
plt.hist(a,100)
fig = plt.show()

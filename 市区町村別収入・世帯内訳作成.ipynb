# %%
import pandas as pd
import numpy as np

# %%
a = pd.read_csv("/Users/01017387/Desktop/しごと/data/car用/年齢、収入、職業_2013/群馬県.csv").dropna()
# b = pd.read_csv("/Users/01017387/Desktop/しごと/data/car用/年齢、収入、職業_2013/奈良県.csv")
# print(len(a.head().columns))
a
# Out:
#        ID    県   市町村区    普通世帯総数   25歳未満   25〜34歳   35〜44歳   45〜54歳   55〜64歳  \
# 0   201.0  群馬県    前橋市  131960.0  5160.0  11360.0  19440.0  21160.0  27500.0
# 1   202.0  群馬県    高崎市  151480.0  6500.0  15510.0  25660.0  22460.0  27540.0
# 2   203.0  群馬県    桐生市   45580.0  1500.0   2620.0   5860.0   6340.0   9020.0
# 3   204.0  群馬県   伊勢崎市   77370.0  1790.0   9580.0  15080.0  12940.0  14190.0
# 4   205.0  群馬県    太田市   80400.0  1980.0   8400.0  15380.0  13660.0  14800.0
# 5   206.0  群馬県    沼田市   18990.0   340.0   1540.0   2430.0   3070.0   4360.0
# 6   207.0  群馬県    館林市   29390.0   560.0   2630.0   5030.0   4870.0   6070.0
# 7   208.0  群馬県    渋川市   28330.0   340.0   1600.0   3040.0   4460.0   6680.0
# 8   209.0  群馬県    藤岡市   24080.0   380.0   1250.0   3470.0   4220.0   5970.0
# 9   210.0  群馬県    富岡市   16650.0   100.0   1000.0   2500.0   2880.0   4130.0
# 10  211.0  群馬県    安中市   22100.0   170.0    990.0   2860.0   3340.0   5040.0
# ...

# %%
#県名＋市名をくっつけた列が必要
#全て数字が入っている
#職業欄は後で除いても大丈夫だと思われる
#くっつけ実験
c= pd.concat([a,b])
c.head()
c.tail()
c.shape
a.shape
# c
# Out:
# (20, 26)

# %%
pref = ["青森県","岩手県","宮城県","秋田県","山形県","福島県","茨城県","栃木県","群馬県","埼玉県","千葉県","東京都",
        "神奈川県","新潟県","富山県","石川県","福井県","山梨県","長野県","岐阜県","静岡県","愛知県","三重県","滋賀県","京都府",
        "大阪府","兵庫県","奈良県","和歌山県","鳥取県","島根県","岡山県","広島県","山口県","徳島県","香川県","愛媛県","高知県",
        "福岡県","佐賀県","長崎県","熊本県","大分県","宮崎県","鹿児島県","沖縄県"]

# %%
a = pd.read_csv("/Users/01017387/Desktop/しごと/data/car用/年齢、収入、職業_2013/北海道.csv")
a.columns=(['ID', '県', '市区町村', '普通世帯総数', '25歳未満', '25〜34歳', '35〜44歳', '45〜54歳','55〜64歳',
     '65歳以上', '自営業主', '農林・漁業業主', '商工・その他の業主', '雇用者','会社・団体・公社又は個人に雇われている者',
     '官公庁', '労働者派遣事業所の派遣社員', 'パート・アルバイト・その他', '無職','学生', 'その他', '300万円未満', '300〜500万円',
     '500〜700万円', '700〜1000万円', '1000万円以上'])
c = a.copy()
cnt = 0
confirm = []
confirm.append(a.columns)
for p in pref:
    exec('b = pd.read_csv("/Users/01017387/Desktop/しごと/data/car用/年齢、収入、職業_2013/'+p+'.csv")')
    confirm.append(b.columns)
    b.columns=(['ID', '県', '市区町村', '普通世帯総数', '25歳未満', '25〜34歳', '35〜44歳', '45〜54歳','55〜64歳',
         '65歳以上', '自営業主', '農林・漁業業主', '商工・その他の業主', '雇用者','会社・団体・公社又は個人に雇われている者',
         '官公庁', '労働者派遣事業所の派遣社員', 'パート・アルバイト・その他', '無職','学生', 'その他', '300万円未満', '300〜500万円',
         '500〜700万円', '700〜1000万円', '1000万円以上'])
    #変数名の中で年齢、金額単位がない場合があるので、リネームが必要
    
    c= pd.concat([c,b])
#     cnt +=1
#     if cnt >2:
#         break
# cna = c.isnull()
a = c.dropna()
con = pd.DataFrame(confirm)

# %%
c["市区町村名"] = c["県"]+c["市区町村"]
#場所の入れ替え
c = c.ix[:,['ID', '市区町村名', '県', '市区町村', '普通世帯総数', '25歳未満', '25〜34歳', '35〜44歳', '45〜54歳',
       '55〜64歳', '65歳以上', '自営業主', '農林・漁業業主', '商工・その他の業主', '雇用者',
       '会社・団体・公社又は個人に雇われている者', '官公庁', '労働者派遣事業所の派遣社員', 'パート・アルバイト・その他', '無職',
       '学生', 'その他', '300万円未満', '300〜500万円', '500〜700万円', '700〜1000万円',
       '1000万円以上']]
c.head()
# Out:
#       ID   市区町村名    県 市区町村    普通世帯総数  25歳未満   25〜34歳    35〜44歳    45〜54歳  \
# 0  100.0  北海道札幌市  北海道  札幌市  863550.0  33430  83760.0  125710.0  135880.0
# 1  101.0  北海道中央区  北海道  中央区  116680.0   5070  13830.0   14360.0   17860.0
# 2  102.0   北海道北区  北海道   北区  121860.0   8290  11680.0   19150.0   19270.0
# 3  103.0   北海道東区  北海道   東区  116520.0   3690  11980.0   20160.0   15540.0
# 4  104.0  北海道白石区  北海道  白石区  102470.0   3900  12810.0   16210.0   17150.0
#
#      55〜64歳    ...     労働者派遣事業所の派遣社員  パート・アルバイト・その他        無職     学生  \
# 0  155430.0    ...           12540.0        73510.0  189010.0  11040
# 1   16220.0    ...            1000.0         8120.0   20240.0   1500
# 2   21150.0    ...            1580.0         9570.0   26100.0   3570
# 3   20340.0    ...            1610.0        10890.0   23750.0    910
# 4   16610.0    ...            1780.0         8850.0   19010.0    800
#
#         その他   300万円未満  300〜500万円  500〜700万円  700〜1000万円  1000万円以上
# ...

# %%
c.to_csv("/Users/01017387/Desktop/しごと/コード/03_配車最適化/00_model/data/shunyu_setai_2015.csv")
con.to_csv("/Users/01017387/Desktop/しごと/コード/03_配車最適化/00_model/data/confirm.csv")

# %%
c.columns
# Out:
# Index(['ID', '県', '市区町村', '普通世帯総数', '25歳未満', '25〜34歳', '35〜44歳', '45〜54歳',
#        '55〜64歳', '65歳以上', '自営業主', '農林・漁業業主', '商工・その他の業主', '雇用者',
#        '会社・団体・公社又は個人に雇われている者', '官公庁', '労働者派遣事業所の派遣社員', 'パート・アルバイト・その他', '無職',
#        '学生', 'その他', '300万円未満', '300〜500万円', '500〜700万円', '700〜1000万円',
#        '1000万円以上', '市区町村名'],
#       dtype='object')

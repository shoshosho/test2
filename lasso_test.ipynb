# %%
import sys
sys.path.append("/Users/01017387/Desktop/git関連/LassoVariants")

import pandas as pd

import sklearn as skl
from AlternateLasso.AlternateLinearModel import AlternateLasso
from AlternateLasso.AlternateLinearModel import AlternateLogisticLasso
from EnumLasso.EnumerateLinearModel import EnumLasso

# %%
#データ
data = pd.read_csv("/Users/01017387/Desktop/しごと/data/car用/加工済み/2015_hoyu_daisu.csv",dtype="str")
data.head()
# Out:
#   都道府県名        乗用車        軽         普通        世帯数      車両数/世帯数    普通車両数/世帯数  \
# 0   北海道  2,805,265  1142062  1,663,203  2,734,906  1.025726296     0.608139
# 1    青森    728,253   455493    272,760    586,148   1.24243877  0.465343224
# 2    岩手    738,199   458943    279,256    517,845   1.42552115   0.53926561
# 3    宮城  1,282,869   617560    665,309    961,574   1.33413445  0.691895788
# 4    秋田    594,158   374063    220,095    424,208  1.400628937  0.518837457
#
#       軽車両数/世帯数      軽率     普通率   軽シェア  普通シェア 軽シェア×中古販売数 普通シェア×中古販売数  中古車販売台数
# 0  0.417587296  40.71%  59.29%  3.77%  5.39%     37,693     161,743  199,436
# 1  0.777095546  62.55%  37.45%  1.50%  0.88%     15,033      26,525   41,559
# 2   0.88625554  62.17%  37.83%  1.51%  0.91%     15,147      27,157   42,304
# 3  0.642238663  48.14%  51.86%  2.04%  2.16%     20,382      64,700   85,082
# 4   0.88179148  62.96%  37.04%  1.23%  0.71%     12,346      21,404   33,749

# %%
#余計な文字を取り除く
data = data.drop("都道府県名",axis=1).applymap(lambda x : x.replace(",","").replace("%","")).astype(float)
data.head()
# Out:
#          乗用車          軽         普通        世帯数   車両数/世帯数  普通車両数/世帯数  軽車両数/世帯数  \
# 0  2805265.0  1142062.0  1663203.0  2734906.0  1.025726   0.608139  0.417587
# 1   728253.0   455493.0   272760.0   586148.0  1.242439   0.465343  0.777096
# 2   738199.0   458943.0   279256.0   517845.0  1.425521   0.539266  0.886256
# 3  1282869.0   617560.0   665309.0   961574.0  1.334134   0.691896  0.642239
# 4   594158.0   374063.0   220095.0   424208.0  1.400629   0.518837  0.881791
#
#       軽率    普通率  軽シェア  普通シェア  軽シェア×中古販売数  普通シェア×中古販売数   中古車販売台数
# 0  40.71  59.29  3.77   5.39     37693.0     161743.0  199436.0
# 1  62.55  37.45  1.50   0.88     15033.0      26525.0   41559.0
# 2  62.17  37.83  1.51   0.91     15147.0      27157.0   42304.0
# 3  48.14  51.86  2.04   2.16     20382.0      64700.0   85082.0
# 4  62.96  37.04  1.23   0.71     12346.0      21404.0   33749.0

# %%
X = data.drop("乗用車",axis=1).values
y = data["乗用車"].values

# %%
#モデル
#enum lassoは結構時間かかりそう
mdl_reg = EnumLasso(rho=0.1, modeltype='regression')
mdl_logreg = EnumLasso(rho=0.1, modeltype='classification')

# %%
#fit
mdl_reg.fit(X, y)
# Out:
# /Users/01017387/anaconda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
#結果の確認
print(mdl_reg)
# Out:
# Solution   1: Obj. = 279522.032256
# 	 x_1, Coef. = 2.337398
# 	 x_2, Coef. = 0.457228
# 	 x_3, Coef. = -0.000616
# 	 x_4, Coef. = 263.888209
# 	 x_5, Coef. = -1499.547242
# 	 x_6, Coef. = 1739.696275
# 	 x_7, Coef. = -35.975844
# 	 x_9, Coef. = -232481.998793
# 	 x_10, Coef. = 101797.428364
# 	 x_11, Coef. = -17.033237
# 	 x_12, Coef. = 2.480947
# 	 x_13, Coef. = -0.273391
# 	 intercept, Coef. = 1414.010052
# Solution   2: Obj. = 40.147271
# 	 x_1, Coef. = 2.044461
# 	 x_2, Coef. = 0.607976
# 	 x_3, Coef. = -0.000005
# 	 x_4, Coef. = -8.449514
# 	 x_7, Coef. = 0.073028
# 	 x_10, Coef. = -71.214757
# 	 x_11, Coef. = -31.147195
# 	 x_12, Coef. = 4.533241
# 	 x_13, Coef. = -0.499539
# 	 intercept, Coef. = 11.233145
# Solution   3: Obj. = 6.609853
# 	 x_1, Coef. = 1.016483
# 	 x_2, Coef. = 0.607895
# 	 x_3, Coef. = 0.000001
# 	 x_7, Coef. = 0.027699
# 	 x_10, Coef. = -50.726132
# 	 x_12, Coef. = 4.533149
# 	 x_13, Coef. = -0.499445
# 	 intercept, Coef. = -1.780141
# ...

# %%
#alternateの方を試す
al_reg = AlternateLasso(rho=0.1, verbose=True)
al_logreg = AlternateLogisticLasso(rho=0.1, verbose=True)
# mdl_reg = EnumLasso(rho=0.1, modeltype='regression')
# mdl_logreg = EnumLasso(rho=0.1, modeltype='classification')

# %%
#超早い
al_reg.fit(X, y)
# Out:
# > [feature name, # of alternate feature candidates]
# > [x_1, 0]
# > [x_2, 0]
# > [x_3, 0]
# > [x_4, 0]
# > [x_5, 0]
# > [x_6, 0]
# > [x_7, 0]
# > [x_8, 0]
# > [x_9, 0]
# > [x_10, 0]
# > [x_11, 0]
# > [x_12, 0]
# > [x_13, 0]

# %%
print(al_reg)
# Out:
# Feature: x_1, Coef. = 2.337398
# 	 ** No Alternate Features **
# Feature: x_2, Coef. = 0.457228
# 	 ** No Alternate Features **
# Feature: x_3, Coef. = -0.000616
# 	 ** No Alternate Features **
# Feature: x_4, Coef. = 263.888209
# 	 ** No Alternate Features **
# Feature: x_5, Coef. = -1499.547242
# 	 ** No Alternate Features **
# Feature: x_6, Coef. = 1739.696275
# 	 ** No Alternate Features **
# Feature: x_7, Coef. = -35.975844
# 	 ** No Alternate Features **
# Feature: x_8, Coef. = 0.000000
# 	 ** No Alternate Features **
# Feature: x_9, Coef. = -232481.998793
# 	 ** No Alternate Features **
# Feature: x_10, Coef. = 101797.428364
# 	 ** No Alternate Features **
# Feature: x_11, Coef. = -17.033237
# 	 ** No Alternate Features **
# Feature: x_12, Coef. = 2.480947
# 	 ** No Alternate Features **
# Feature: x_13, Coef. = -0.273391
# 	 ** No Alternate Features **
